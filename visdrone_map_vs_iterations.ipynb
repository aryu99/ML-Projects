# %% [markdown]
# <a href="https://colab.research.google.com/github/aryu99/ML-Projects/blob/master/visdrone_map_vs_iterations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/darknet
# Out:
# /content/drive/My Drive/darknet

# %%
# !make
# !chmod +x ./darknet
# Out:
# chmod +x *.sh

# %%
# !./darknet detector test data/obj.data cfg/yolo-obj_1280.cfg backup/yolo-obj_10000.weights -thresh 0.25 -dont_show -save_labels < data/test.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# car: 100%
# car: 100%
# motor: 72%
# car: 99%
# car: 100%
# motor: 70%
# car: 100%
# pedestrian: 56%
# car: 99%
# motor: 62%
# car: 100%
# car: 100%
# car: 100%
# car: 100%
# car: 100%
# car: 100%
# car: 99%
# car: 99%
# car: 99%
# pedestrian: 66%
# motor: 31%
# person: 72%
# motor: 29%
# car: 99%
# car: 100%
# car: 100%
# car: 96%
# car: 96%
# van : 95%
# van : 39%
# car: 92%
# car: 80%
# car: 81%
# car: 68%
# car: 81%
# car: 96%
# Enter Image Path:  Detection layer: 139 - type = 27
#  Detection layer: 150 - type = 27
#  Detection layer: 161 - type = 27
# data/test/9999979_00000_d_0000051.jpg: Predicted in 504.904000 milli-seconds.
# car: 75%
# van : 93%
# car: 94%
# car: 99%
# car: 96%
# car: 97%
# motor: 45%
# van : 62%
# car: 44%
# car: 64%
# van : 97%
# car: 100%
# car: 42%
# car: 99%
# car: 75%
# car: 90%
# car: 91%
# car: 95%
# car: 100%
# car: 99%
# truck: 97%
# car: 96%
# car: 92%
# van : 97%
# car: 98%
# car: 93%
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolo-obj_1344.cfg backup/yolo-obj_8000.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1   1344 x1344 x   3 -> 1344 x1344 x  32 3.121 BF
#    1 conv     64       3 x 3/ 2   1344 x1344 x  32 ->  672 x 672 x  64 16.647 BF
#    2 conv     64       1 x 1/ 1    672 x 672 x  64 ->  672 x 672 x  64 3.699 BF
#    3 route  1 		                           ->  672 x 672 x  64
#    4 conv     64       1 x 1/ 1    672 x 672 x  64 ->  672 x 672 x  64 3.699 BF
#    5 conv     32       1 x 1/ 1    672 x 672 x  64 ->  672 x 672 x  32 1.850 BF
#    6 conv     64       3 x 3/ 1    672 x 672 x  32 ->  672 x 672 x  64 16.647 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 672 x 672 x  64 0.029 BF
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolo-obj_1120.cfg backup/yolo-obj_7000.weights -iou_thresh 0.75 -ext_output < data/test.txt > result_1120.txt
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1   1120 x1120 x   3 -> 1120 x1120 x  32 2.168 BF
#    1 conv     64       3 x 3/ 2   1120 x1120 x  32 ->  560 x 560 x  64 11.561 BF
#    2 conv     64       1 x 1/ 1    560 x 560 x  64 ->  560 x 560 x  64 2.569 BF
#    3 route  1 		                           ->  560 x 560 x  64
#    4 conv     64       1 x 1/ 1    560 x 560 x  64 ->  560 x 560 x  64 2.569 BF
#    5 conv     32       1 x 1/ 1    560 x 560 x  64 ->  560 x 560 x  32 1.285 BF
#    6 conv     64       3 x 3/ 1    560 x 560 x  32 ->  560 x 560 x  64 11.561 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 560 x 560 x  64 0.020 BF
#    8 conv     64       1 x 1/ 1    560 x 560 x  64 ->  560 x 560 x  64 2.569 BF
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolo-obj_1056.cfg backup/yolo-obj_7000.weights -iou_thresh 0.75 -ext_output < data/test.txt > result_1056.txt
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1   1056 x1056 x   3 -> 1056 x1056 x  32 1.927 BF
#    1 conv     64       3 x 3/ 2   1056 x1056 x  32 ->  528 x 528 x  64 10.277 BF
#    2 conv     64       1 x 1/ 1    528 x 528 x  64 ->  528 x 528 x  64 2.284 BF
#    3 route  1 		                           ->  528 x 528 x  64
#    4 conv     64       1 x 1/ 1    528 x 528 x  64 ->  528 x 528 x  64 2.284 BF
#    5 conv     32       1 x 1/ 1    528 x 528 x  64 ->  528 x 528 x  32 1.142 BF
#    6 conv     64       3 x 3/ 1    528 x 528 x  32 ->  528 x 528 x  64 10.277 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 528 x 528 x  64 0.018 BF
#    8 conv     64       1 x 1/ 1    528 x 528 x  64 ->  528 x 528 x  64 2.284 BF
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolo-obj_960.cfg backup/yolo-obj_7000.weights -iou_thresh 0.75 -ext_output < data/test.txt > result_960.txt
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    960 x 960 x   3 ->  960 x 960 x  32 1.593 BF
#    1 conv     64       3 x 3/ 2    960 x 960 x  32 ->  480 x 480 x  64 8.493 BF
#    2 conv     64       1 x 1/ 1    480 x 480 x  64 ->  480 x 480 x  64 1.887 BF
#    3 route  1 		                           ->  480 x 480 x  64
#    4 conv     64       1 x 1/ 1    480 x 480 x  64 ->  480 x 480 x  64 1.887 BF
#    5 conv     32       1 x 1/ 1    480 x 480 x  64 ->  480 x 480 x  32 0.944 BF
#    6 conv     64       3 x 3/ 1    480 x 480 x  32 ->  480 x 480 x  64 8.493 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 480 x 480 x  64 0.015 BF
#    8 conv     64       1 x 1/ 1    480 x 480 x  64 ->  480 x 480 x  64 1.887 BF
#    9 route  8 2 	                           ->  480 x 480 x 128
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolo-obj_832.cfg backup/yolo-obj_7000.weights -iou_thresh 0.75 -ext_output < data/test.txt > result_832.txt
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    832 x 832 x   3 ->  832 x 832 x  32 1.196 BF
#    1 conv     64       3 x 3/ 2    832 x 832 x  32 ->  416 x 416 x  64 6.380 BF
#    2 conv     64       1 x 1/ 1    416 x 416 x  64 ->  416 x 416 x  64 1.418 BF
#    3 route  1 		                           ->  416 x 416 x  64
#    4 conv     64       1 x 1/ 1    416 x 416 x  64 ->  416 x 416 x  64 1.418 BF
#    5 conv     32       1 x 1/ 1    416 x 416 x  64 ->  416 x 416 x  32 0.709 BF
#    6 conv     64       3 x 3/ 1    416 x 416 x  32 ->  416 x 416 x  64 6.380 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 416 x 416 x  64 0.011 BF
#    8 conv     64       1 x 1/ 1    416 x 416 x  64 ->  416 x 416 x  64 1.418 BF
#    9 route  8 2 	                           ->  416 x 416 x 128
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolo-obj_608.cfg backup/yolo-obj_7000.weights -iou_thresh 0.75 -ext_output < data/test.txt > result_608.txt
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    8 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    9 route  8 2 	                           ->  304 x 304 x 128
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolo-obj_416.cfg backup/yolo-obj_7000.weights -iou_thresh 0.75 -ext_output < data/test.txt > result_416.txt
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    8 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    9 route  8 2 	                           ->  208 x 208 x 128
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_10000.weights -iou_thresh 0.75 -ext_output < data/test.txt > result.txt
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    768 x 768 x   3 ->  768 x 768 x  32 1.019 BF
#    1 conv     64       3 x 3/ 2    768 x 768 x  32 ->  384 x 384 x  64 5.436 BF
#    2 conv     64       1 x 1/ 1    384 x 384 x  64 ->  384 x 384 x  64 1.208 BF
#    3 route  1 		                           ->  384 x 384 x  64
#    4 conv     64       1 x 1/ 1    384 x 384 x  64 ->  384 x 384 x  64 1.208 BF
#    5 conv     32       1 x 1/ 1    384 x 384 x  64 ->  384 x 384 x  32 0.604 BF
#    6 conv     64       3 x 3/ 1    384 x 384 x  32 ->  384 x 384 x  64 5.436 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 384 x 384 x  64 0.009 BF
#    8 conv     64       1 x 1/ 1    384 x 384 x  64 ->  384 x 384 x  64 1.208 BF
#    9 route  8 2 	                           ->  384 x 384 x 128
# ...
